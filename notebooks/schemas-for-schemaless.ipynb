# %%
import scoped_mapping
import sqlite3
import pandas as pd
import yaml
import sys
import datetime
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/vt/f297tpjn6n1b6dwkcwhhnmxm0000gp/T/ipykernel_47334/2254685734.py in <module>
# ----> 1 import scoped_mapping
#       2 import sqlite3
#       3 import pandas as pd
#       4 import yaml
#       5 import sys
#
# ~/Documents/gitrepos/schemas-for-schemaless/venv/lib/python3.9/site-packages/scoped_mapping/__init__.py in <module>
#       2 from pkg_resources import get_distribution, DistributionNotFound
#       3 from strsimpy.cosine import Cosine
# ----> 4 from tdda import rexpy
#       5 from xml.etree import ElementTree
#       6 import pandas as pd
#
# ModuleNotFoundError: No module named 'tdda'

# %% [markdown]
# ## Convert (from xlsx/gsheet) to tsv to yaml
#
# ```Bash
# ./linkml_model_enrichment/infer_model.py tsv2model \
# --class_name synbio_element \
# --schema_name synbio \
# --enum-columns species /Users/MAM/Documents/gitrepos/linkml-model-enrichment_keep/local/Ontology_example_20210317_P2B1_allmods_categorytype_different_scores_per_mod-1.tsv > \
# /Users/MAM/Ontology_example_20210317_P2B1_allmods_categorytype_different_scores_per_mod-1_experimental.yaml
# ```
#
# ---
#
# ```Bash
# ./linkml_model_enrichment/infer_model.py tsv2model \
# --class_name condensed_traits_NCBI \
# --schema_name organism \
# --sep ',' \
# /Users/MAM/Documents/gitrepos/bacteria-archaea-traits/output/condensed_traits_NCBI.csv > /Users/MAM/condensed_traits_NCBI.yaml
#
# ```
#
# ---
#
# ```Bash
# curl -L -o rdftab https://github.com/ontodev/rdftab.rs/releases/download/v0.1.1/rdftab-x86_64-apple-darwin
# chmod +x rdftab
# curl -L -o prefix.sql https://raw.githubusercontent.com/ontodev/rdftab.rs/master/test/prefix.sql
#
# curl -L -o pato.owl http://purl.obolibrary.org/obo/pato.owl
# curl -L -o uberon.owl https://raw.githubusercontent.com/obophenotype/uberon/master/uberon.owl
# curl -L -o micro.owl http://purl.obolibrary.org/obo/micro.owl
# rm multi_obo.db
# sqlite3 multi_obo.db < prefix.sql
# ./rdftab multi_obo.db < pato.owl
# ./rdftab multi_obo.db < uberon.owl
#
#
# ./rdftab multi_obo.db < micro.owl
#
#
# ```

# %%
# yaml_file = "/Users/MAM/Ontology_example_20210317_P2B1_allmods_categorytype_different_scores_per_mod-1_experimental.yaml"

yaml_file = "/Users/MAM/condensed_traits_NCBI.yaml"

# cd_ontologies = "ncbitaxon,obi"
cd_ontologies = "omp,micro,ncbitaxon"

rr = 5
chars_to_wo = "\\.\\_\\-"

max_string_dist = 0.05

# shingle/ngram size
string_dist_arg=2

# orgocat = "organism"
# selected_enum = "species_enum"
selected_enum = "cell_shape_enum"

cat_split = selected_enum.split('_')
bare_cat = cat_split[0]

# rdftab_file = "/Users/MAM/Documents/gitrepos/scoped-mapping/semantic-sql/db/ncbitaxon.db"

rdftab_file = "/Users/MAM/multi_obo.db"

# %%
# ~ 30 sec for NCBItaxon with transitive closure over subclasses
#   does that make a difference
#   satements table indexed pretty thoroughly

# use straight rdftab (don't need to ecpose transitive closure from seamatnic sql? other features?)

# any reason to use
#   get_sqlite_con
#   or timed_query?


rdftab_con = sqlite3.connect(rdftab_file)

rdftab_query = """
select distinct s1.subject as class, lower(s1.value) as label
from statements s1
join statements s2
on s1.subject = s2.subject

where s1.predicate = 'rdfs:label' 
and s1.subject = s1.stanza
and s2.predicate = 'rdf:type'
and s2.object = 'owl:Class'

-- limit 999
"""

ct = datetime.datetime.now()
print(ct)

rdftab_res = pd.read_sql(rdftab_query, rdftab_con)

ct = datetime.datetime.now()
print(ct)

rdftab_res
# Out:
# 2021-07-12 17:11:06.723676
# 2021-07-12 17:11:06.951849
#                 class                                      label
# 0         BFO:0000002                                 continuant
# 1         BFO:0000003                                  occurrent
# 2         BFO:0000004                     independent continuant
# 3         BFO:0000015                                    process
# 4         BFO:0000016                                disposition
# ...               ...                                        ...
# 17958  UBERON:8410063  myenteric nerve plexus of small intestine
# 17959  UBERON:8410064  submucous nerve plexus of small intestine
# 17960  UBERON:8410065          lymph node follicle marginal zone
# 17961  UBERON:8410066                      lymph node paracortex
# 17962  UBERON:8410067          lymph node interfollicular cortex
#
# [17963 rows x 2 columns]

# %%
x = rdftab_res['class'].str.split(pat=':|#_', expand=True)
x_col_count = len(x.columns)
x_col_count
na_flag = x[x_col_count-1].isna()
x[x_col_count-1][na_flag] = x[x_col_count-2]

rdftab_res['id_rhs'] = x[x_col_count-1]

# %%
fake_lab_flag = rdftab_res['label'] == rdftab_res['id_rhs']

rdftab_res = rdftab_res[ ~ fake_lab_flag]

# may need to update prefix sql

# rdftab_res.to_csv("rdftab_res.csv")

# %%
temp_flag = rdftab_res['class'].str.contains('^http', case=False, flags=0, na=None, regex=True)
temp_flag.value_counts()
# Out:
# False    17963
# Name: class, dtype: int64

# %%
rdftab_res = scoped_mapping.add_prefix_col(rdftab_res, "class", "ontology_prefix")

rdftab_res

# a small number of IDs like obo:NCBITaxon#_species_group remain
# Out:
#                 class                                      label   id_rhs  \
# 0         BFO:0000002                                 continuant  0000002
# 1         BFO:0000003                                  occurrent  0000003
# 2         BFO:0000004                     independent continuant  0000004
# 3         BFO:0000015                                    process  0000015
# 4         BFO:0000016                                disposition  0000016
# ...               ...                                        ...      ...
# 17958  UBERON:8410063  myenteric nerve plexus of small intestine  8410063
# 17959  UBERON:8410064  submucous nerve plexus of small intestine  8410064
# 17960  UBERON:8410065          lymph node follicle marginal zone  8410065
# 17961  UBERON:8410066                      lymph node paracortex  8410066
# 17962  UBERON:8410067          lymph node interfollicular cortex  8410067
#
#       ontology_prefix
# 0                 BFO
# 1                 BFO
# 2                 BFO
# 3                 BFO
# 4                 BFO
# ...               ...
# 17958          UBERON
# 17959          UBERON
# 17960          UBERON
# 17961          UBERON
# 17962          UBERON
#
# [17963 rows x 4 columns]

# %%
rdftab_res['ontology_prefix'].value_counts()
# Out:
# UBERON    15180
# PATO       2726
# GO           40
# BFO          11
# CARO          4
# CL            2
# Name: ontology_prefix, dtype: int64

# %%
yaml_model = scoped_mapping.read_yaml_model(yaml_file)

avaialbe_enums = scoped_mapping.get_avaialbe_enums(yaml_model)
# print(avaialbe_enums)
permissible_values = scoped_mapping.get_permissible_values(yaml_model, selected_enum)
# print(permissible_values)

woedf = scoped_mapping.get_whiteout_frame(raw_list=permissible_values)
woedl = scoped_mapping.get_wo_list(woed_frame=woedf)

# woedl

# %%
woed_merge = woedf.merge(rdftab_res, how = "left", left_on = 'woed', right_on = 'label')
woed_merge
# Out:
#               raw           woed         class        label   id_rhs  \
# 0      triangular     triangular  PATO:0001875   triangular  0001875
# 1     pleomorphic    pleomorphic  PATO:0001356  pleomorphic  0001356
# 2         branced        branced           NaN          NaN      NaN
# 3              NA             na           NaN          NaN      NaN
# 4         spindle        spindle           NaN          NaN      NaN
# 5           flask          flask           NaN          NaN      NaN
# 6        bacillus       bacillus           NaN          NaN      NaN
# 7          vibrio         vibrio           NaN          NaN      NaN
# 8          spiral         spiral           NaN          NaN      NaN
# 9          square         square  PATO:0000413       square  0000413
# 10         tailed         tailed           NaN          NaN      NaN
# 11  coccobacillus  coccobacillus           NaN          NaN      NaN
# 12           ring           ring           NaN          NaN      NaN
# 13          disc            disc           NaN          NaN      NaN
# 14      irregular      irregular           NaN          NaN      NaN
# 15     spirochete     spirochete           NaN          NaN      NaN
# 16           star           star           NaN          NaN      NaN
# 17         coccus         coccus           NaN          NaN      NaN
# 18       fusiform       fusiform  PATO:0002400     fusiform  0002400
# 19       filament       filament           NaN          NaN      NaN
#
#    ontology_prefix
# 0             PATO
# 1             PATO
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 9             PATO
# 10             NaN
# 11             NaN
# 12             NaN
# 13             NaN
# 14             NaN
# 15             NaN
# 16             NaN
# 17             NaN
# 18            PATO
# 19             NaN

# %%
c_flag = woed_merge['class'].isna()
c_subset = woed_merge[c_flag]
c = c_subset['raw']

# %%
d = set(woed_merge['raw']) - set(c)

# %%
# string_dist_arg = shingle/ngram size


ct = datetime.datetime.now()
print(ct)

yaml_mapped = scoped_mapping.search_get_annotations_wrapper(
    c,
    bad_chars=chars_to_wo,
    cat_name=bare_cat,
    ontoprefix=cd_ontologies,
    query_fields="",
    string_dist_arg=string_dist_arg,
    rr=rr,
)

ct = datetime.datetime.now()
print(ct)

yaml_mapped
# Out:
# 2021-07-12 17:11:11.334380
# 2021-07-12 17:11:23.598108
#     category       raw     query                         name  \
# 0       cell  bacillus  bacillus                     bacillus
# 4       cell  bacillus  bacillus                     bacillus
# 8       cell  bacillus  bacillus                     bacillus
# 9       cell  bacillus  bacillus   Bacillus sp. 'Bacillus M9'
# 10      cell  bacillus  bacillus  Bacillus sp. 'Bacillus M12'
# ..       ...       ...       ...                          ...
# 234     cell    vibrio    vibrio                      Pacinia
# 235     cell    vibrio    vibrio                   Microspira
# 236     cell    vibrio    vibrio                      Pacinia
# 237     cell    vibrio    vibrio                   Listonella
# 238     cell    vibrio    vibrio                     Beneckea
#
#      string_dist_rank string_dist            obo_id  \
# 0                   1       0.000     MICRO:0000401
# 4                   2       0.000     MICRO:0000401
# 8                   3       0.000       OMP:0000076
# 9                   4       0.174  NCBITaxon:427569
# 10                  5       0.184  NCBITaxon:427557
# ..                ...         ...               ...
# 234                11       1.000     NCBITaxon:662
# 235                12       1.000     NCBITaxon:662
# 236                13       1.000     NCBITaxon:662
# 237                14       1.000     NCBITaxon:662
# 238                15       1.000     NCBITaxon:662
#
#                            label  search_rank ontology_prefix  \
# 0                       bacillus            1           MICRO
# 4                       bacillus            1           MICRO
# 8               rod-shaped cells            2             OMP
# 9     Bacillus sp. 'Bacillus M9'            3       NCBITAXON
# 10   Bacillus sp. 'Bacillus M12'            4       NCBITAXON
# ..                           ...          ...             ...
# 234                       Vibrio            1       NCBITAXON
# 235                       Vibrio            1       NCBITAXON
# 236                       Vibrio            1       NCBITAXON
# 237                       Vibrio            1       NCBITAXON
# 238                       Vibrio            1       NCBITAXON
#
#                    scope        type  \
# 0                  label       label
# 4      has_exact_synonym  annotation
# 8                synonym     synonym
# 9                  label       label
# 10                 label       label
# ..                   ...         ...
# 234    hasRelatedSynonym     synonym
# 235  has_related_synonym  annotation
# 236  has_related_synonym  annotation
# 237  has_related_synonym  annotation
# 238  has_related_synonym  annotation
#
#                                                  iri ontology_name
# 0       http://purl.obolibrary.org/obo/MICRO_0000401         micro
# 4       http://purl.obolibrary.org/obo/MICRO_0000401         micro
# 8         http://purl.obolibrary.org/obo/OMP_0000076           omp
# 9    http://purl.obolibrary.org/obo/NCBITaxon_427569     ncbitaxon
# 10   http://purl.obolibrary.org/obo/NCBITaxon_427557     ncbitaxon
# ..                                               ...           ...
# 234     http://purl.obolibrary.org/obo/NCBITaxon_662     ncbitaxon
# 235     http://purl.obolibrary.org/obo/NCBITaxon_662     ncbitaxon
# 236     http://purl.obolibrary.org/obo/NCBITaxon_662     ncbitaxon
# 237     http://purl.obolibrary.org/obo/NCBITaxon_662     ncbitaxon
# 238     http://purl.obolibrary.org/obo/NCBITaxon_662     ncbitaxon
#
# [245 rows x 14 columns]

# %%
any_successes = set(d.union(yaml_mapped['raw']))

no_resutls = set(permissible_values) - any_successes

no_resutls
# Out:
# set()

# %%
best_acceptable = scoped_mapping.get_best_acceptable(
    mappings=yaml_mapped, max_string_dist=max_string_dist
)

# %%
woed_merge_success = woed_merge[ ~ c_flag].copy()

woed_merge_success["string_dist_rank"] = 1
woed_merge_success["search_rank"] = 1
woed_merge_success["string_dist"] = 0
woed_merge_success["scope"] = "label"
woed_merge_success["type"] = "label"

woed_merge_success["name"] = woed_merge_success["label"]
woed_merge_success["category"] = bare_cat

woed_merge_success.rename(columns={"woed": "query", "class": "obo_id"}, inplace=True)

woed_merge_success = scoped_mapping.add_prefix_col(woed_merge_success, "obo_id", "ontology_prefix")

# %%
woed_merge_success = scoped_mapping.add_prefix_col(woed_merge_success, "obo_id", "ontology_prefix")

# %%
woed_merge_success["ontology_prefix"] = woed_merge_success[
    "ontology_prefix"
].str.upper()

best_acceptable["method"] = "best OLS search result"
woed_merge_success["method"] = "rdftab"

best_acceptable = best_acceptable.append(woed_merge_success, ignore_index=True)

best_acceptable.drop(["ontology_name", "iri", "id_rhs"], axis=1, inplace=True)

best_acceptable
# Out:
#    category            raw          query           name  string_dist_rank  \
# 0      cell       bacillus       bacillus       bacillus                 1
# 1      cell  coccobacillus  coccobacillus  coccobacillus                 1
# 2      cell         coccus         coccus         coccus                 1
# 3      cell       filament       filament       filament                 1
# 4      cell          flask          flask          flask                 1
# 5      cell      irregular      irregular      irregular                 1
# 6      cell         spiral         spiral         spiral                 1
# 7      cell     spirochete     spirochete     spirochete                 1
# 8      cell         vibrio         vibrio         Vibrio                 1
# 9      cell     triangular     triangular     triangular                 1
# 10     cell    pleomorphic    pleomorphic    pleomorphic                 1
# 11     cell         square         square         square                 1
# 12     cell       fusiform       fusiform       fusiform                 1
#
#     string_dist         obo_id             label  search_rank ontology_prefix  \
# 0           0.0  MICRO:0000401          bacillus            1           MICRO
# 1           0.0  MICRO:0000366     coccobacillus            1           MICRO
# 2           0.0  MICRO:0000402            coccus            1           MICRO
# 3           0.0  MICRO:0000042     cell filament            1           MICRO
# 4           0.0  MICRO:0000406  pear-shaped cell            2           MICRO
# 5           0.0  MICRO:0000333    irregular cell            1           MICRO
# 6           0.0   PATO:0000404            coiled            1           MICRO
# 7           0.0    OMP:0000125        spirochete            1             OMP
# 8           0.0  NCBITaxon:662            Vibrio            1       NCBITAXON
# 9           0.0   PATO:0001875        triangular            1            PATO
# 10          0.0   PATO:0001356       pleomorphic            1            PATO
# 11          0.0   PATO:0000413            square            1            PATO
# 12          0.0   PATO:0002400          fusiform            1            PATO
#
#                 scope        type                  method
# 0               label       label  best OLS search result
# 1               label       label  best OLS search result
# 2               label       label  best OLS search result
# 3   has_exact_synonym  annotation  best OLS search result
# 4   has_exact_synonym  annotation  best OLS search result
# 5   has_broad_synonym  annotation  best OLS search result
# 6             synonym     synonym  best OLS search result
# 7               label       label  best OLS search result
# 8               label       label  best OLS search result
# 9               label       label                  rdftab
# 10              label       label                  rdftab
# 11              label       label                  rdftab
# 12              label       label                  rdftab

# %%
best_acceptable['ontology_prefix'].value_counts()
# Out:
# MICRO        7
# PATO         4
# OMP          1
# NCBITAXON    1
# Name: ontology_prefix, dtype: int64

# %%
no_acceptable_mappings = scoped_mapping.get_no_acceptable_mappings(
    yaml_mapped, best_acceptables=best_acceptable
)
# no_acceptable_mappings

# %%
# query obtained result but not acceptable
# also look for erroneous mappings above
no_acceptable_queries = set(no_acceptable_mappings["query"])
needs_followup = no_acceptable_queries.union(no_resutls)
needs_followup

# use this for commenting enums that need manual intervention?
# Out:
# {'branced', 'disc', 'na', 'ring', 'spindle', 'star', 'tailed'}

# %%
# silently saves back into model object
# repeat as necessary for other enums

# add confidence value

# also save mappings as SSSOM

scoped_mapping.rewrite_yaml(yaml_model, selected_enum, best_acceptable)

# %%
yaml.safe_dump(yaml_model, sys.stdout, default_flow_style=False)
# Out:
# classes:
#   condensed_traits_NCBI:
#     slot_usage: {}
#     slots:
#     - tax_id
#     - species_tax_id
#     - data_source
#     - org_name
#     - species
#     - genus
#     - family
#     - order
#     - class
#     - phylum
#     - superkingdom
#     - gram_stain
#     - metabolism
#     - pathways
#     - carbon_substrates
#     - sporulation
#     - motility
#     - range_tmp
#     - range_salinity
#     - cell_shape
#     - isolation_source
#     - d1_lo
#     - d1_up
#     - d2_lo
#     - d2_up
#     - doubling_h
#     - genome_size
#     - gc_content
#     - coding_genes
#     - optimum_tmp
#     - optimum_ph
#     - growth_tmp
#     - rRNA16S_genes
#     - tRNA_genes
#     - ref_id
# default_prefix: organism
# description: organism
# enums:
#   cell_shape_enum:
#     permissible_values:
#       NA:
#         description: NA
#       bacillus:
#         description: bacillus
#         meaning: MICRO:0000401
#       branced:
#         description: branced
#       coccobacillus:
#         description: coccobacillus
#         meaning: MICRO:0000366
#       coccus:
#         description: coccus
#         meaning: MICRO:0000402
#       'disc ':
#         description: 'disc '
#       filament:
#         description: cell filament
#         meaning: MICRO:0000042
#       flask:
#         description: pear-shaped cell
#         meaning: MICRO:0000406
#       fusiform:
#         description: fusiform
#         meaning: PATO:0002400
#       irregular:
#         description: irregular cell
#         meaning: MICRO:0000333
#       pleomorphic:
#         description: pleomorphic
#         meaning: PATO:0001356
#       ring:
#         description: ring
#       spindle:
#         description: spindle
#       spiral:
#         description: coiled
#         meaning: PATO:0000404
#       spirochete:
#         description: spirochete
#         meaning: OMP:0000125
#       square:
#         description: square
#         meaning: PATO:0000413
#       star:
#         description: star
#       tailed:
#         description: tailed
#       triangular:
#         description: triangular
#         meaning: PATO:0001875
#       vibrio:
#         description: Vibrio
#         meaning: NCBITaxon:662
#   data_source_enum:
#     permissible_values:
#       amend-shock:
#         description: amend-shock
#       bacdive-microa:
#         description: bacdive-microa
#       campedelli:
#         description: campedelli
#       corkrey:
#         description: corkrey
#       edwards:
#         description: edwards
#       engqvist:
#         description: engqvist
#       faprotax:
#         description: faprotax
#       fierer:
#         description: fierer
#       genbank:
#         description: genbank
#       gold:
#         description: gold
#       jemma-refseq:
#         description: jemma-refseq
#       kegg:
#         description: kegg
#       kremer:
#         description: kremer
#       masonmm:
#         description: masonmm
#       mediadb:
#         description: mediadb
#       methanogen:
#         description: methanogen
#       microbe-directory:
#         description: microbe-directory
#       nielsensl:
#         description: nielsensl
#       pasteur:
#         description: pasteur
#       patric:
#         description: patric
#       prochlorococcus:
#         description: prochlorococcus
#       protraits:
#         description: protraits
#       roden-jin:
#         description: roden-jin
#       rrndb:
#         description: rrndb
#       schulz-jorgensen:
#         description: schulz-jorgensen
#       silva:
#         description: silva
#   gram_stain_enum:
#     permissible_values:
#       NA:
#         description: NA
#       negative:
#         description: negative
#       positive:
#         description: positive
#   metabolism_enum:
#     permissible_values:
#       NA:
#         description: NA
#       aerobic:
#         description: aerobic
#       anaerobic:
#         description: anaerobic
#       facultative:
#         description: facultative
#       microaerophilic:
#         description: microaerophilic
#       obligate aerobic:
#         description: obligate aerobic
#       obligate anaerobic:
#         description: obligate anaerobic
#       strictly anaerobic:
#         description: strictly anaerobic
#   motility_enum:
#     permissible_values:
#       NA:
#         description: NA
#       axial filament:
#         description: axial filament
#       flagella:
#         description: flagella
#       gliding:
#         description: gliding
#       'no':
#         description: 'no'
#       'yes':
#         description: 'yes'
#   rRNA16S_genes_enum:
#     permissible_values:
#       '1':
#         description: '1'
#       '10':
#         description: '10'
#       '11':
#         description: '11'
#       '12':
#         description: '12'
#       '13':
#         description: '13'
#       '14':
#         description: '14'
#       '15':
#         description: '15'
#       '16':
#         description: '16'
#       '17':
#         description: '17'
#       '2':
#         description: '2'
#       '3':
#         description: '3'
#       '4':
#         description: '4'
#       '5':
#         description: '5'
#       '6':
#         description: '6'
#       '7':
#         description: '7'
#       '8':
#         description: '8'
#       '9':
#         description: '9'
#       NA:
#         description: NA
#   range_salinity_enum:
#     permissible_values:
#       NA:
#         description: NA
#       euryhaline:
#         description: euryhaline
#       extreme-halophilic:
#         description: extreme-halophilic
#       halophilic:
#         description: halophilic
#       halotolerant:
#         description: halotolerant
#       moderate-halophilic:
#         description: moderate-halophilic
#       non-halophilic:
#         description: non-halophilic
#       stenohaline:
#         description: stenohaline
#   range_tmp_enum:
#     permissible_values:
#       NA:
#         description: NA
#       extreme thermophilic:
#         description: extreme thermophilic
#       facultative psychrophilic:
#         description: facultative psychrophilic
#       mesophilic:
#         description: mesophilic
#       psychrophilic:
#         description: psychrophilic
#       psychrotolerant:
#         description: psychrotolerant
#       thermophilic:
#         description: thermophilic
#       thermotolerant:
#         description: thermotolerant
#   sporulation_enum:
#     permissible_values:
#       NA:
#         description: NA
#       'no':
#         description: 'no'
#       'yes':
#         description: 'yes'
#   superkingdom_enum:
#     permissible_values:
#       Archaea:
#         description: Archaea
#       Bacteria:
#         description: Bacteria
# id: https://w3id.org/organism
# imports:
# - linkml:types
# name: organism
# prefixes:
#   linkml: https://w3id.org/link/linkml/
#   organism: https://w3id.org/organism
# slots:
#   carbon_substrates:
#     examples:
#     - value: NA
#     range: string
#   cell_shape:
#     examples:
#     - value: NA
#     range: cell_shape_enum
#   class:
#     examples:
#     - value: Alphaproteobacteria
#     range: string
#   coding_genes:
#     examples:
#     - value: NA
#     range: string
#   d1_lo:
#     examples:
#     - value: NA
#     range: string
#   d1_up:
#     examples:
#     - value: NA
#     range: string
#   d2_lo:
#     examples:
#     - value: NA
#     range: string
#   d2_up:
#     examples:
#     - value: NA
#     range: string
#   data_source:
#     examples:
#     - value: silva
#     range: data_source_enum
#   doubling_h:
#     examples:
#     - value: '1.7'
#     range: string
#   family:
#     examples:
#     - value: Sphingomonadaceae
#     range: string
#   gc_content:
#     examples:
#     - value: NA
#     range: string
#   genome_size:
#     examples:
#     - value: NA
#     range: string
#   genus:
#     examples:
#     - value: Zymomonas
#     range: string
#   gram_stain:
#     examples:
#     - value: NA
#     range: gram_stain_enum
#   growth_tmp:
#     examples:
#     - value: '30'
#     range: string
#   isolation_source:
#     examples:
#     - value: NA
#     range: string
#   metabolism:
#     examples:
#     - value: NA
#     range: metabolism_enum
#   motility:
#     examples:
#     - value: NA
#     range: motility_enum
#   optimum_ph:
#     examples:
#     - value: NA
#     range: string
#   optimum_tmp:
#     examples:
#     - value: NA
#     range: string
#   order:
#     examples:
#     - value: Sphingomonadales
#     range: string
#   org_name:
#     examples:
#     - value: Zymomonas mobilis
#     range: string
#   pathways:
#     examples:
#     - value: NA
#     range: string
#   phylum:
#     examples:
#     - value: Proteobacteria
#     range: string
#   rRNA16S_genes:
#     examples:
#     - value: NA
#     range: rRNA16S_genes_enum
#   range_salinity:
#     examples:
#     - value: NA
#     range: range_salinity_enum
#   range_tmp:
#     examples:
#     - value: NA
#     range: range_tmp_enum
#   ref_id:
#     examples:
#     - value: '20237'
#     range: string
#   species:
#     examples:
#     - value: Zymomonas mobilis
#     range: string
#   species_tax_id:
#     examples:
#     - value: '542'
#     range: integer
#   sporulation:
#     examples:
#     - value: NA
#     range: sporulation_enum
#   superkingdom:
#     examples:
#     - value: Bacteria
#     range: superkingdom_enum
#   tRNA_genes:
#     examples:
#     - value: NA
#     range: string
#   tax_id:
#     examples:
#     - value: '542'
#     range: integer
# types: {}

# %% [markdown]
# ---

# %%
scoped_mapping.get_multi_term_patterns(rdftab_res, 'class', 'ontology_prefix')

# %%
# 2 minutes and memory hungry for NCBItaxon

ct = datetime.datetime.now()
print(ct)

# handle empty, string or list?
# what about ontologies that import a lot of terms?
# what about multi-ontology rdftabs
discovered_id_pattern = scoped_mapping.discover_id_pattern(list(rdftab_res['class']))

ct = datetime.datetime.now()
print(ct)

# may not give 100% coverage
# with elimination of SOME but not all textual NCBItaxon IDs
#   the discovered ID pattern is 'NCBITaxon:\\d+'
discovered_id_pattern

# %%
problem_file = "/Users/MAM/icbo.xlsx"
problem_spreadsheet = pd.read_excel(problem_file)
problem_spreadsheet

# %%
pso = problem_spreadsheet[orgocat]
pso

# %%
pso_vc = pso.value_counts()
pso_vc

# %%
pso_unique = list(pso_vc.index)
pso_unique

# %%
# orgolist = ['homo--sapiens', 'MUS.MUSCULUS', 'NCBITaxon:9598', 'NCBITaxon:Rhinoceros']


# # # woed = scoped_mapping.whiteout(raw_string="", char_string="\\.\\_\\-")

# woedf = scoped_mapping.get_whiteout_frame(raw_list = orgolist)

# woedl = scoped_mapping.get_wo_list(woed_frame=woedf)
# # # woedl

# # # socr = scoped_mapping.search_over_category('organisms', woedl, ontology_phrase=cd_ontologies,
# # #                                                         qf_phrase='', row_req=rr)

# # # search_over_category returns list of frames?
# # # part of get_csr_frame
# # #  # part of search_get_annotations_wrapper

# # csr_frame = scoped_mapping.get_csr_frame(woedl, bad_chars=chars_to_wo, category_name=orgocat,
# #                   ontoprefix=cd_ontologies, query_fields='', rows_requested=rr)

# # # # lowercase
# # # scoped_mapping.one_ols_submission(woed, ontology_phrase='ncbitaxon,obi', qf_phrase='', row_req=5)

# # first_csr_row = csr_frame.iloc[1,:]
# # # category	raw	query	label	iri	obo_id	ontology_name	ontology_prefix	search_rank

# # scoped_mapping.get_label_like(first_csr_row)
# # # embedded in get_bulk_label_like
# # #   embedded in search_get_annotations_wrapper
# # prep_for_label_like
# # #   embedded in search_get_annotations_wrapper
# # merge_and_compare
# # #   embedded in search_get_annotations_wrapper

woedf = scoped_mapping.get_whiteout_frame(raw_list=pso_unique)
woedl = scoped_mapping.get_wo_list(woed_frame=woedf)

# better retention of counts
aw_res = scoped_mapping.search_get_annotations_wrapper(
    raw_list=woedl,
    bad_chars=chars_to_wo,
    cat_name=orgocat,
    ontoprefix=cd_ontologies,
    query_fields="",
    rr=rr,
    string_dist_arg=2,
)

# aw_res

# scoped_mapping.get_best_acceptable(aw_res)

# %%
id_series = rdftab_res.subject
id_series

# %%
# was expecting 'NCBITaxon:[a-z0-9]+'
id_series[id_series.str.contains("^NCBITaxon:[^\\d]")]

# %%
# https://tdda.readthedocs.io/en/v1.0.30/rexpy.html
# check predicate oio:hasOBONamespace
id_series[id_series.str.contains("^obo:NCBITaxon#")]

# %%
# vectorize?
decomposed = scoped_mapping.decompose_series(pd.Series(orgolist), discovered_id_pattern)
# make_tidy_col is embedded

# REMOVE PREFIX FROM remaining_tidied SEE NCBITaxon:Rhinoceros

decomposed

# %%
demposed_with_prefix = scoped_mapping.add_prefix_col(
    dataframe=decomposed, col_with_prefixes="extract", prefix_col="onto_prefix"
)

# %%
demposed_with_prefix

# %% [markdown]
# ```Python
# def get_multi_term_patterns(dataframe, col_with_prefixes, prefix_col):
#
# def get_no_acceptable_mappings(all_mappings, best_acceptables):
# def add_unique_to_list(uniquelist, non_unique):
# def add_overrides(dataframe, incol, outcol, override_dict):
# def flag_canonical(dataframe, incol, outcol, canonicals):
#
# # yaml specific
# def rewrite_yaml(model, enum, best_acceptable):
#
# # biosample specific
# def get_package_dictionary(biosample_packages_file):
# def env_package_nomralizastion(dataframe, col_to_normalize, id_replacement_rule):
# ```
